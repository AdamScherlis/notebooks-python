# %%
# 2022-07
# some godforsaken mobile game I wasn't even playing

# %%
from math import ceil

# %%
math.ceil(3.5)
# Out:
# 4

# %%
banks = 1
gems = 0
day = 0
while day < 2*366:
    print(day, banks, gems)
    need = 100 - gems
    days = ceil(need / banks)
    day += days
    gems += days * banks
    banks += 1
    gems -= 100
# Out:
# 0 1 0
# 100 2 0
# 150 3 0
# 184 4 2
# 209 5 2
# 229 6 2
# 246 7 4
# 260 8 2
# 273 9 6
# 284 10 5
# 294 11 5
# 303 12 4
# 311 13 0
# 319 14 4
# 326 15 2
# 333 16 7
# 339 17 3
# 345 18 5
# 351 19 13
# 356 20 8
# 361 21 8
# 366 22 13
# 370 23 1
# 375 24 16
# 379 25 12
# 383 26 12
# 387 27 16
# 391 28 24
# 394 29 8
# 398 30 24
# 401 31 14
# 404 32 7
# 407 33 3
# 410 34 2
# 413 35 4
# 416 36 9
# 419 37 17
# 422 38 28
# 424 39 4
# 427 40 21
# 429 41 1
# 432 42 24
# 434 43 8
# 437 44 37
# 439 45 25
# 441 46 15
# 443 47 7
# 445 48 1
# 448 49 45
# 450 50 43
# 452 51 43
# 454 52 45
# 456 53 49
# 457 54 2
# 459 55 10
# 461 56 20
# 463 57 32
# 465 58 46
# 466 59 4
# 468 60 22
# 470 61 42
# 471 62 3
# 473 63 27
# 475 64 53
# 476 65 17
# 478 66 47
# 479 67 13
# 481 68 47
# 482 69 15
# 484 70 53
# 485 71 23
# 487 72 65
# 488 73 37
# 489 74 10
# 491 75 58
# 492 76 33
# 493 77 9
# 495 78 63
# 496 79 41
# 497 80 20
# 498 81 0
# 500 82 62
# 501 83 44
# 502 84 27
# 503 85 11
# 505 86 81
# 506 87 67
# ...

# %%
(100 - 153)/204
# Out:
# -0.25980392156862747
