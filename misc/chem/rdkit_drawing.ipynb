# %%
# 2024-01
# drawing molecules nicely
# (for Anki cards)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole

size = (120, 120)  # Smaller figures than the default.

# %%
import matplotlib.pyplot as plt

# %%
# %cd misc/chem
# Out:
# /home/adam/Dropbox/personal/projects/ipy/misc/chem
# /usr/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
m = Chem.MolFromSmiles('Cn1cnc2c1c(=O)n(c(=O)n2C)C')

# %%
def drawmol(smiles, 
res = 500
opts = Draw.MolDrawOptions()
opts.bondLineWidth = 3.
im = Chem.Draw.MolToImage(m, size=(res, res), options=opts)
acsize = 5
scale = 1
fig = plt.figure(figsize=(acsize / scale, acsize / scale))
ax = plt.axes([0, 0, scale, scale], frameon=True)
ax.imshow(im)
ax.axis('off')
fig.savefig('molecule.png', bbox_inches='tight', pad_inches=0)

# %%
fig.gca().axis('off')
fig.savefig('molecule.png', bbox_inches='tight', pad_inches=0)

# %%
fig, ax = Draw.MolToMPL(m, size=size)
for a in ax.get_children():
    if isinstance(a, Text):
        a.set_backgroundcolor('white')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 fig, ax = Draw.MolToMPL(m, size=size)
#       2 for a in ax.get_children():
#       3     if isinstance(a, Text):
#
# TypeError: cannot unpack non-iterable Figure object
