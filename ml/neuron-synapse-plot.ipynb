# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([(231, 8617), (302, 7500), (250000,10000000), (960000,1000000000),(86000000000, 150000000000000)])

# %%
pairs = [(231, 8617), 
         (302, 7500), 
         (250e3, 10e6), 
         (960e3, 1e9),
         (71e6, 1e12),
         (200e6, 4.49e11),
         (760e6, 1e13),
         (8.6e10, 1.5e14)]

# %%
fig1, ax1 = plt.subplots()
ax1.set_aspect('equal')
plt.plot([np.log10(p[0]) for p in pairs], [np.log10(p[1]/p[0]) for p in pairs], marker='o')
plt.plot(np.arange(2, 12), [3]*10)
plt.plot(np.arange(2, 12), np.arange(1.5,3.2,1.7/9))

# %%
fig1, ax1 = plt.subplots()
ax1.set_aspect('equal')
plt.plot([np.log10(p[0]) for p in pairs], [np.log10(p[1]) for p in pairs], marker='o')
plt.plot(np.arange(2, 12), np.arange(5, 15))

# %%
[(p[1]/p[0]) for p in pairs]
# Out:
# [37.303030303030305,
#  24.834437086092716,
#  40.0,
#  1041.6666666666667,
#  14084.507042253521,
#  2245.0,
#  13157.894736842105,
#  1744.1860465116279]

# %%
175/2
# Out:
# 87.5
