# %%
# 2022-12
# despite the name, it's just a table of all 2-byte characters

# %%
0x40 * 0x20
# Out:
# 2048

# %%
for j in range(0x40):
    for i in range(0x20):
        print((bytes([0xc0+i, 0x80+j]).decode() if i>1 else '.'), end=' ')
    print()
# Out:
# . .  À Ā ŀ ƀ ǀ Ȁ ɀ ʀ ˀ ̀ ̀ ΀ π Ѐ р Ҁ Ӏ Ԁ Հ ր ׀ ؀ ـ ڀ ۀ ܀ ݀ ހ ߀
# . .  Á ā Ł Ɓ ǁ ȁ Ɂ ʁ ˁ ́ ́ ΁ ρ Ё с ҁ Ӂ ԁ Ձ ց ׁ ؁ ف ځ ہ ܁ ݁ ށ ߁
# . .  Â Ă ł Ƃ ǂ Ȃ ɂ ʂ ˂ ̂ ͂ ΂ ς Ђ т ҂ ӂ Ԃ Ղ ւ ׂ ؂ ق ڂ ۂ ܂ ݂ ނ ߂
# . .  Ã ă Ń ƃ ǃ ȃ Ƀ ʃ ˃ ̃ ̓ ΃ σ Ѓ у ҃ Ӄ ԃ Ճ փ ׃ ؃ ك ڃ ۃ ܃ ݃ ރ ߃
# . .  Ä Ą ń Ƅ Ǆ Ȅ Ʉ ʄ ˄ ̄ ̈́ ΄ τ Є ф ҄ ӄ Ԅ Մ ք ׄ ؄ ل ڄ ۄ ܄ ݄ ބ ߄
# . .  Å ą Ņ ƅ ǅ ȅ Ʌ ʅ ˅ ̅ ͅ ΅ υ Ѕ х ҅ Ӆ ԅ Յ օ ׅ ؅ م څ ۅ ܅ ݅ ޅ ߅
# . .  Æ Ć ņ Ɔ ǆ Ȇ Ɇ ʆ ˆ ̆ ͆ Ά φ І ц ҆ ӆ Ԇ Ն ֆ ׆ ؆ ن چ ۆ ܆ ݆ ކ ߆
# . .  Ç ć Ň Ƈ Ǉ ȇ ɇ ʇ ˇ ̇ ͇ · χ Ї ч ҇ Ӈ ԇ Շ և ׇ ؇ ه ڇ ۇ ܇ ݇ އ ߇
# . .  È Ĉ ň ƈ ǈ Ȉ Ɉ ʈ ˈ ̈ ͈ Έ ψ Ј ш ҈ ӈ Ԉ Ո ֈ ׈ ؈ و ڈ ۈ ܈ ݈ ވ ߈
# . .  É ĉ ŉ Ɖ ǉ ȉ ɉ ʉ ˉ ̉ ͉ Ή ω Љ щ ҉ Ӊ ԉ Չ ։ ׉ ؉ ى ډ ۉ ܉ ݉ މ ߉
# . .  Ê Ċ Ŋ Ɗ Ǌ Ȋ Ɋ ʊ ˊ ̊ ͊ Ί ϊ Њ ъ Ҋ ӊ Ԋ Պ ֊ ׊ ؊ ي ڊ ۊ ܊ ݊ ފ ߊ
# . .  Ë ċ ŋ Ƌ ǋ ȋ ɋ ʋ ˋ ̋ ͋ ΋ ϋ Ћ ы ҋ Ӌ ԋ Ջ ֋ ׋ ؋ ً ڋ ۋ ܋ ݋ ދ ߋ
# . .  Ì Č Ō ƌ ǌ Ȍ Ɍ ʌ ˌ ̌ ͌ Ό ό Ќ ь Ҍ ӌ Ԍ Ռ ֌ ׌ ، ٌ ڌ ی ܌ ݌ ތ ߌ
# . .  Í č ō ƍ Ǎ ȍ ɍ ʍ ˍ ̍ ͍ ΍ ύ Ѝ э ҍ Ӎ ԍ Ս ֍ ׍ ؍ ٍ ڍ ۍ ܍ ݍ ލ ߍ
# . .  Î Ď Ŏ Ǝ ǎ Ȏ Ɏ ʎ ˎ ̎ ͎ Ύ ώ Ў ю Ҏ ӎ Ԏ Վ ֎ ׎ ؎ َ ڎ ێ ܎ ݎ ގ ߎ
# ...

# %%
2**11 - 2**7
# Out:
# 1920

# %%
print('a', end='')
print('b', end='')
# Out:
# ab
